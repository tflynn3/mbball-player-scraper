# %%
from scraper import get_all_schools, get_roster, get_player_gamelog
import pandas as pd
from pprint import pprint

# %%
# Create a schools dataframe
s = get_all_schools()
schools_df = pd.DataFrame(s)
print(schools_df.head())
# Out:
#                   school_name                      school_link  \
# 0                         NaN                              NaN
# 1  Abilene Christian Wildcats  /cbb/schools/abilene-christian/
# 2           Air Force Falcons          /cbb/schools/air-force/
# 3                  Akron Zips              /cbb/schools/akron/
# 4        Alabama A&M Bulldogs         /cbb/schools/alabama-am/
#
#                  location year_min year_max years     g wins losses  \
# 0                     NaN      NaN      NaN   NaN   NaN  NaN    NaN
# 1          Abilene, Texas     1971     2022    12   356  195    161
# 2  USAF Academy, Colorado     1958     2022    65  1780  771   1009
# 3             Akron, Ohio     1902     2022    71  1649  981    668
# 4         Normal, Alabama     2000     2022    23   655  250    405
#
#   win_loss_pct     srs     sos poll_final conf_champ_count  \
# 0          NaN     NaN     NaN        NaN              NaN
# 1         .548   -8.41   -6.47          0                0
# 2         .433   -2.83    1.33          0                1
# 3         .595   -0.16   -1.54          0                9
# 4         .382  -16.95  -11.36          0                1
#
#   conf_champ_post_count ncaa_count ncaa_final_four_count ncaa_champ_count
# 0                   NaN        NaN                   NaN              NaN
# 1                     2          2                     0                0
# 2                     0          4                     0                0
# 3                     4          4                     0                0
# 4                     1          1                     0                0

# %%
# Get Jayhawks
my_school = schools_df.loc[schools_df['school_name'] == 'Kansas Jayhawks'].to_dict('records')[0]
pprint(my_school)

# Check if school played this year
if my_school['year_max'] == '2022':
    print(f'\nThe {my_school["school_name"]} played this year!')
# Out:
# {'conf_champ_count': '63',
#  'conf_champ_post_count': '15',
#  'g': '3228',
#  'location': 'Lawrence, Kansas',
#  'losses': '877',
#  'ncaa_champ_count': '3',
#  'ncaa_count': '49',
#  'ncaa_final_four_count': '15',
#  'poll_final': '46',
#  'school_link': '/cbb/schools/kansas/',
#  'school_name': 'Kansas Jayhawks',
#  'sos': '7.25',
#  'srs': '15.83',
#  'win_loss_pct': '.728',
#  'wins': '2351',
#  'year_max': '2022',
#  'year_min': '1899',
#  'years': '124'}
#
# The Kansas Jayhawks played this year!

# %%
# Get team roster
ku_roster = get_roster(my_school["school_link"])
roster_df = pd.DataFrame(ku_roster)
print(roster_df.head())
# Out:
# Could not get player link...skipping player
#             player                          player_link number class pos  \
# 0     Ochai Agbaji     /cbb/players/ochai-agbaji-1.html     30    SR   G
# 1  Christian Braun  /cbb/players/christian-braun-1.html      2    JR   G
# 2  David McCormack  /cbb/players/david-mccormack-1.html     33    SR   F
# 3     Jalen Wilson     /cbb/players/jalen-wilson-1.html     10    SO   F
# 4    Dajuan Harris    /cbb/players/dajuan-harris-1.html      3    JR   G
#
#   height weight           hometown               high_school       rsci  \
# 0    6-5    210    Kansas City, MO               Oak Park HS
# 1    6-6    205  Overland Park, KS  Blue Valley Northwest HS
# 2   6-10    265        Norfolk, VA          Oak Hill Academy  30 (2018)
# 3    6-8    215         Denton, TX          John H. Guyer HS  51 (2019)
# 4    6-1    160       Columbia, MO            Rock Bridge HS
#
#                        summary
# 0   19.7 Pts, 5.1 Reb, 1.6 Ast
# 1   14.6 Pts, 6.4 Reb, 2.6 Ast
# 2   10.1 Pts, 7.1 Reb, 1.0 Ast
# 3   10.9 Pts, 7.0 Reb, 1.7 Ast
# 4    5.2 Pts, 1.4 Reb, 4.4 Ast

# %%
# Initialize a player games array
ku_player_game_stats = []

# A gamelog is a list of all games a certain player has played
# regardless of what season it was
# Now let's get the gamelogs from KU's current roster
for ku_player in ku_roster:
    # Get player game log
    p = get_player_gamelog(ku_player['player_link'])
    # Player gamelog has some empty rows
    ku_player_game_stats += p

ku_gamelog_df = pd.DataFrame(ku_player_game_stats).dropna()
ku_gamelog_df
# Out:
#        season   date_game         school_name game_location        opp_name  \
# 0     2018-19  2019-01-09              Kansas                           TCU
# 1     2018-19  2019-01-12              Kansas             @          Baylor
# 2     2018-19  2019-01-14              Kansas                         Texas
# 3     2018-19  2019-01-19              Kansas             @   West Virginia
# 4     2018-19  2019-01-21              Kansas                    Iowa State
# ...       ...         ...                 ...           ...             ...
# 1173  2017-18  2018-02-15  Jacksonville State             @    Murray State
# 1174  2017-18  2018-02-17  Jacksonville State             @     Austin Peay
# 1175  2017-18  2018-02-22  Jacksonville State                       Belmont
# 1176  2017-18  2018-03-01  Jacksonville State             N  Tennessee Tech
# 1177  2017-18  2018-03-02  Jacksonville State             N    Murray State
#
#      game_type game_result gs  mp fg  ... ft_pct orb drb trb ast stl blk tov  \
# 0          REG           W  0  25  3  ...          1   3   4   1   2   1   0
# 1          REG           W  0  21  4  ...   .500   1   2   3   0   1   0   0
# 2          REG           W  0  25  2  ...          0   4   4   2   1   0   0
# 3          REG           L  0   4  0  ...          1   2   3   0   0   0   3
# 4          REG           W  0  16  3  ...          1   4   5   0   0   1   2
# ...        ...         ... ..  .. ..  ...    ...  ..  ..  ..  ..  ..  ..  ..
# 1173       REG           L  0   2  0  ...          0   0   0   0   0   0   0
# 1174       REG           L  0  26  5  ...   .700   4   6  10   2   1   2   0
# 1175       REG           W  0  20  3  ...  1.000   3   7  10   4   0   0   0
# 1176    CTOURN           W  0   8  0  ...          0   1   1   1   0   0   1
# 1177    CTOURN           L  0   3  0  ...          0   3   3   0   0   0   0
#
#      pf pts
# 0     2   7
# 1     2  10
# 2     1   4
# 3     0   0
# 4     5   8
# ...  ..  ..
# 1173  1   0
# 1174  3  18
# 1175  3  10
# 1176  2   0
# 1177  1   0
#
# [1178 rows x 30 columns]

# %%
# Let's review data...
ku_gamelog_df.to_csv('go_hawks.csv')

# %%
# Looks like the correct data, but it needs to joined with previous data frames
# I'm gonna repeat code...

# Initialize a player games array
ku_player_game_stats = []

# A gamelog is a list of all games a certain player has played
# regardless of what season it was
# Now let's get the gamelogs from KU's current roster
for ku_player in ku_roster:
    # Get player game log
    p = get_player_gamelog(ku_player['player_link'])
    # Player gamelog has some empty rows
    for game in p:
        ku_player_game = {}
        # add player data
        ku_player_game.update(ku_player)
        # add game data
        ku_player_game.update(game)
        ku_player_game_stats.append(ku_player_game)

ku_gamelog_df = pd.DataFrame(ku_player_game_stats).dropna()
ku_gamelog_df
# Out:
#             player                       player_link number class pos height  \
# 0     Ochai Agbaji  /cbb/players/ochai-agbaji-1.html     30    SR   G    6-5
# 1     Ochai Agbaji  /cbb/players/ochai-agbaji-1.html     30    SR   G    6-5
# 2     Ochai Agbaji  /cbb/players/ochai-agbaji-1.html     30    SR   G    6-5
# 3     Ochai Agbaji  /cbb/players/ochai-agbaji-1.html     30    SR   G    6-5
# 4     Ochai Agbaji  /cbb/players/ochai-agbaji-1.html     30    SR   G    6-5
# ...            ...                               ...    ...   ...  ..    ...
# 1173    Cam Martin    /cbb/players/cam-martin-1.html     31    SR   F    6-9
# 1174    Cam Martin    /cbb/players/cam-martin-1.html     31    SR   F    6-9
# 1175    Cam Martin    /cbb/players/cam-martin-1.html     31    SR   F    6-9
# 1176    Cam Martin    /cbb/players/cam-martin-1.html     31    SR   F    6-9
# 1177    Cam Martin    /cbb/players/cam-martin-1.html     31    SR   F    6-9
#
#      weight         hometown        high_school rsci  ... ft_pct orb drb trb  \
# 0       210  Kansas City, MO        Oak Park HS       ...          1   3   4
# 1       210  Kansas City, MO        Oak Park HS       ...   .500   1   2   3
# 2       210  Kansas City, MO        Oak Park HS       ...          0   4   4
# 3       210  Kansas City, MO        Oak Park HS       ...          1   2   3
# 4       210  Kansas City, MO        Oak Park HS       ...          1   4   5
# ...     ...              ...                ...  ...  ...    ...  ..  ..  ..
# 1173    230        Yukon, OK  Yukon High School       ...          0   0   0
# 1174    230        Yukon, OK  Yukon High School       ...   .700   4   6  10
# 1175    230        Yukon, OK  Yukon High School       ...  1.000   3   7  10
# 1176    230        Yukon, OK  Yukon High School       ...          0   1   1
# 1177    230        Yukon, OK  Yukon High School       ...          0   3   3
#
#      ast stl blk tov pf pts
# 0      1   2   1   0  2   7
# 1      0   1   0   0  2  10
# 2      2   1   0   0  1   4
# 3      0   0   0   3  0   0
# 4      0   0   1   2  5   8
# ...   ..  ..  ..  .. ..  ..
# 1173   0   0   0   0  1   0
# 1174   2   1   2   0  3  18
# 1175   4   0   0   0  3  10
# 1176   1   0   0   1  2   0
# 1177   0   0   0   0  1   0
#
# [1178 rows x 41 columns]

# %%
# Let's review data... again....
ku_gamelog_df.to_csv('go_hawks_again.csv')

# %%
# If we want to join with team data...
# make this async tho

player_game_stats = []

for school in s:
    # get school roster
    try:
        roster = get_roster(school["school_link"])
        # Now let's get the gamelogs from each team
        for player in roster:
            # Get player game log
            gl = get_player_gamelog(player['player_link'])
            for game in gl:
                player_game_temp = {}
                # add player data
                player_game_temp.update(player)
                # add game data
                player_game_t
                emp.update(game)
                # add school data
                player_game_temp.update(school)
                player_game_stats.append(player_game_temp)
    except KeyError:
        print("School did not have URL for this season...")

full_gamelog_df = pd.DataFrame(player_game_stats).dropna()
full_gamelog_df
# Out:
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# School did not have URL...
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
# Could not get player link...skipping player
#               player                       player_link number class pos  \
# 0       Coryon Mason  /cbb/players/coryon-mason-1.html     20    SR   G
# 1       Coryon Mason  /cbb/players/coryon-mason-1.html     20    SR   G
# 2       Coryon Mason  /cbb/players/coryon-mason-1.html     20    SR   G
# 3       Coryon Mason  /cbb/players/coryon-mason-1.html     20    SR   G
# 4       Coryon Mason  /cbb/players/coryon-mason-1.html     20    SR   G
# ...              ...                               ...    ...   ...  ..
# 285890    Alex Vargo    /cbb/players/alex-vargo-1.html     14         G
# 285891    Alex Vargo    /cbb/players/alex-vargo-1.html     14         G
# 285892    Alex Vargo    /cbb/players/alex-vargo-1.html     14         G
# 285893    Alex Vargo    /cbb/players/alex-vargo-1.html     14         G
# 285894    Alex Vargo    /cbb/players/alex-vargo-1.html     14         G
#
#        height weight           hometown       high_school rsci  ... losses  \
# 0         6-0    190  Oklahoma City, OK     Douglass (OK)       ...    161
# 1         6-0    190  Oklahoma City, OK     Douglass (OK)       ...    161
# 2         6-0    190  Oklahoma City, OK     Douglass (OK)       ...    161
# 3         6-0    190  Oklahoma City, OK     Douglass (OK)       ...    161
# 4         6-0    190  Oklahoma City, OK     Douglass (OK)       ...    161
# ...       ...    ...                ...               ...  ...  ...    ...
# 285890    6-5    210       Wheeling, WV  Wheeling Park HS       ...    741
# 285891    6-5    210       Wheeling, WV  Wheeling Park HS       ...    741
# 285892    6-5    210       Wheeling, WV  Wheeling Park HS       ...    741
# 285893    6-5    210       Wheeling, WV  Wheeling Park HS       ...    741
# 285894    6-5    210       Wheeling, WV  Wheeling Park HS       ...    741
#
#        win_loss_pct    srs    sos poll_final conf_champ_count  \
# 0              .548  -8.41  -6.47          0                0
# 1              .548  -8.41  -6.47          0                0
# 2              .548  -8.41  -6.47          0                0
# 3              .548  -8.41  -6.47          0                0
# 4              .548  -8.41  -6.47          0                0
# ...             ...    ...    ...        ...              ...
# 285890         .395  -8.42  -3.43          0                0
# 285891         .395  -8.42  -3.43          0                0
# 285892         .395  -8.42  -3.43          0                0
# 285893         .395  -8.42  -3.43          0                0
# 285894         .395  -8.42  -3.43          0                0
#
#        conf_champ_post_count ncaa_count ncaa_final_four_count ncaa_champ_count
# 0                          2          2                     0                0
# 1                          2          2                     0                0
# 2                          2          2                     0                0
# 3                          2          2                     0                0
# 4                          2          2                     0                0
# ...                      ...        ...                   ...              ...
# 285890                     0          0                     0                0
# 285891                     0          0                     0                0
# 285892                     0          0                     0                0
# 285893                     0          0                     0                0
# 285894                     0          0                     0                0
#
# [285895 rows x 58 columns]

# %%
full_gamelog_df.to_csv('all_gamelog_data_2022.csv')
